# %%
# !pip install matplotlib
# !pip install numpy

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define similarity measures for comparison
similarity_measures = ["Cosine Similarity", "Euclidean Distance", "Manhattan Distance", "Jaccard Similarity", "Hamming Distance", "Pearson Correlation", "Spearman Rank Correlation", "Kendall Tau Correlation", "Mahalanobis Distance", "Chebyshev Distance"]

# Define hypothetical performance scores for each measure in the context of FAISS
# Scores are on a scale from 1 to 10 (10 being the best)
performance_scores = {
    "Cosine Similarity": [8, 9, 10, 9, 9],
    "Euclidean Distance": [7, 8, 7, 8, 7],
    "Manhattan Distance": [6, 7, 7, 8, 7],
    "Jaccard Similarity": [7, 6, 6, 7, 6],
    "Hamming Distance": [4, 8, 5, 7, 7],
    "Pearson Correlation": [8, 7, 8, 8, 8],
    "Spearman Rank Correlation": [8, 7, 8, 8, 8],
    "Kendall Tau Correlation": [7, 7, 7, 7, 7],
    "Mahalanobis Distance": [9, 6, 9, 7, 8],
    "Chebyshev Distance": [5, 9, 6, 7, 8],
}

# Define the labels and number of variables
labels = ["Accuracy", "Speed", "Scalability", "Ease of Use", "Memory Usage"]
num_vars = len(labels)

# Define angles for radar chart
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]

# Initialize the radar chart
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Plot each similarity measure
for measure, scores in performance_scores.items():
    scores += scores[:1]  # Repeat the first value to close the circle
    ax.plot(angles, scores, label=measure)
    ax.fill(angles, scores, alpha=0.1)

# Add labels and title
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
plt.title("Performance Comparison of Similarity Measures in FAISS")

# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define similarity measures for comparison
similarity_measures = ["Cosine Similarity", "Euclidean Distance", "Manhattan Distance", "Jaccard Similarity", "Hamming Distance", "Pearson Correlation", "Spearman Rank Correlation", "Kendall Tau Correlation", "Mahalanobis Distance", "Chebyshev Distance"]

# Define hypothetical performance scores for each measure in a general context
# Scores are on a scale from 1 to 10 (10 being the best)
performance_scores = {
    "Cosine Similarity": [8, 9, 10, 9, 9],
    "Euclidean Distance": [7, 8, 7, 8, 7],
    "Manhattan Distance": [6, 7, 7, 8, 7],
    "Jaccard Similarity": [7, 6, 6, 7, 6],
    "Hamming Distance": [4, 8, 5, 7, 7],
    "Pearson Correlation": [8, 7, 8, 8, 8],
    "Spearman Rank Correlation": [8, 7, 8, 8, 8],
    "Kendall Tau Correlation": [7, 7, 7, 7, 7],
    "Mahalanobis Distance": [9, 6, 9, 7, 8],
    "Chebyshev Distance": [5, 9, 6, 7, 8],
}

# Define the labels and number of variables
labels = ["Accuracy", "Speed", "Scalability", "Ease of Use", "Memory Usage"]
num_vars = len(labels)

# Define angles for radar chart
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]

# Initialize the radar chart
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Plot each similarity measure
for measure, scores in performance_scores.items():
    scores += scores[:1]  # Repeat the first value to close the circle
    ax.plot(angles, scores, label=measure)
    ax.fill(angles, scores, alpha=0.1)

# Add labels and title
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
plt.title("Performance Comparison of Similarity Measures")

# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))

# Show the plot
plt.show()
